# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data.csv')

# %%
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
data["Star color"].tail(60)
# Out:
# 180             Red
# 181             Red
# 182             Red
# 183             Red
# 184             Red
# 185             Red
# 186             Red
# 187             Red
# 188             Red
# 189             Red
# 190             Red
# 191             Red
# 192             Red
# 193             Red
# 194             Red
# 195             Red
# 196             Red
# 197             Red
# 198             Red
# 199             Red
# 200            Blue
# 201            Blue
# 202            Blue
# 203            Blue
# 204            Blue
# 205            Blue
# 206            Blue
# 207            Blue
# 208            Blue
# 209            Blue
# 210      Blue-white
# 211      Blue-white
# 212      Blue-white
# 213      Blue-white
# 214            Blue
# 215            Blue
# 216      Blue-white
# 217      Blue-white
# 218      Blue-white
# 219    yellow-white
# 220            Blue
# 221            Blue
# 222            Blue
# 223            Blue
# 224            Blue
# ...

# %%
data_dc = {
    'temperature': data['Temperature (K)'],
    'luminosity': data['Luminosity(L/Lo)'],
    'radius': data['Radius(R/Ro)'],
    'magnitude': data['Absolute magnitude(Mv)'],
    'star_type': data['Star type'],
    'star_color': data['Star color'],
    'spectral_class': data['Spectral Class'],
}

# %%
R = data[data["Star type"] == 0]
B = data[data["Star type"] == 1]
W = data[data["Star type"] == 2]
M = data[data["Star type"] == 3]
S = data[data["Star type"] == 4]
H = data[data["Star type"] == 5]

# %%
sO = data[data["Spectral Class"] == 'O']
sB = data[data["Spectral Class"] == 'B']
sA = data[data["Spectral Class"] == 'A']
sF = data[data["Spectral Class"] == 'F']
sG = data[data["Spectral Class"] == 'G']
sK = data[data["Spectral Class"] == 'K']
sM = data[data["Spectral Class"] == 'M']

# %%
fig , ax = plt.subplots(figsize = (13,10))

ax.scatter(np.log(R["Temperature (K)"]), np.log(R["Luminosity(L/Lo)"]),15, label = 'Red dwarfs')
ax.scatter(np.log(B["Temperature (K)"]), np.log(B["Luminosity(L/Lo)"]),15, label = 'Brown dwarfs')
ax.scatter(np.log(W["Temperature (K)"]), np.log(W["Luminosity(L/Lo)"]),15, label = 'White dwarfs')
ax.scatter(np.log(M["Temperature (K)"]), np.log(M["Luminosity(L/Lo)"]),15, label = 'Main sequence stars')
ax.scatter(np.log(S["Temperature (K)"]), np.log(S["Luminosity(L/Lo)"]),15, label = 'Supergiants')
ax.scatter(np.log(H["Temperature (K)"]), np.log(H["Luminosity(L/Lo)"]),15, label = 'Hypergiants')

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.grid()

# %%
fig , ax = plt.subplots(figsize = (13,10))

ax.scatter(np.log(R["Temperature (K)"]), np.log(R["Absolute magnitude(Mv)"]),15, label = 'Red dwarfs')
ax.scatter(np.log(B["Temperature (K)"]), np.log(B["Absolute magnitude(Mv)"]),15, label = 'Brown dwarfs')
ax.scatter(np.log(W["Temperature (K)"]), np.log(W["Absolute magnitude(Mv)"]),15, label = 'White dwarfs')
ax.scatter(np.log(M["Temperature (K)"]), np.log(M["Absolute magnitude(Mv)"]),15, label = 'Main sequence stars')
ax.scatter(np.log(S["Temperature (K)"]), np.log(S["Absolute magnitude(Mv)"]),15, label = 'Supergiants')
ax.scatter(np.log(H["Temperature (K)"]), np.log(H["Absolute magnitude(Mv)"]),15, label = 'Hypergiants')

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Absolute magnitude(Mv)")
ax.grid()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig , ax = plt.subplots(figsize = (13,10))

sO = data[data["Spectral Class"] == 'O']
sB = data[data["Spectral Class"] == 'B']
sA = data[data["Spectral Class"] == 'A']
sF = data[data["Spectral Class"] == 'F']
sG = data[data["Spectral Class"] == 'G']
sK = data[data["Spectral Class"] == 'K']
sM = data[data["Spectral Class"] == 'M']

ax.scatter(np.log(sO["Temperature (K)"]), np.log(sO["Luminosity(L/Lo)"]),15, label = 'Spectral class O')
ax.scatter(np.log(sB["Temperature (K)"]), np.log(sB["Luminosity(L/Lo)"]),15, label = 'Spectral class B')
ax.scatter(np.log(sA["Temperature (K)"]), np.log(sA["Luminosity(L/Lo)"]),15, label = 'Spectral class A')
ax.scatter(np.log(sF["Temperature (K)"]), np.log(sF["Luminosity(L/Lo)"]),15, label = 'Spectral class F')
ax.scatter(np.log(sG["Temperature (K)"]), np.log(sG["Luminosity(L/Lo)"]),15, label = 'Spectral class G')
ax.scatter(np.log(sK["Temperature (K)"]), np.log(sK["Luminosity(L/Lo)"]),15, label = 'Spectral class K')
ax.scatter(np.log(sM["Temperature (K)"]), np.log(sM["Luminosity(L/Lo)"]),15, label = 'Spectral class M')

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.grid()

# %%
fig , ax = plt.subplots(figsize = (13,10))

R = data[data["Star color"] == 'Red']
BW = data[data["Star color"] == 'Blue White' or 'Blue white' or 'Blue-white' or 'Blue white ' or 'Blue-White']
W = data[data["Star color"] == 'White' or 'Whitish' or 'white']
B = data[data["Star color"] == 'Blue' or 'Blue ']
O = data[data["Star color"] == 'Orange' or 'Orange-Red']
YW = data[data["Star color"] == 'yellow-white' or 'White-Yellow' or 'Yellowish White']
Y = data[data["Star color"] == 'yellowish' or 'Yellowish']

ax.scatter(np.log(R["Temperature (K)"]), np.log(R["Luminosity(L/Lo)"]),15, label = 'Red')
ax.scatter(np.log(BW["Temperature (K)"]), np.log(BW["Luminosity(L/Lo)"]),15, label = 'Blue White')
ax.scatter(np.log(W["Temperature (K)"]), np.log(W["Luminosity(L/Lo)"]),15, label = 'White')
ax.scatter(np.log(B["Temperature (K)"]), np.log(B["Luminosity(L/Lo)"]),15, label = 'Blue')
ax.scatter(np.log(O["Temperature (K)"]), np.log(O["Luminosity(L/Lo)"]),15, label = 'Orange')
ax.scatter(np.log(YM["Temperature (K)"]), np.log(YM["Luminosity(L/Lo)"]),15, label = 'Yellow White')
ax.scatter(np.log(Y["Temperature (K)"]), np.log(Y["Luminosity(L/Lo)"]),15, label = 'Yellowish')

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-0c24387fd204> in <module>
#       2
#       3 R = data[data["Star color"] == 'Red']
# ----> 4 BW = data[data["Star color"] == 'Blue White' or 'Blue white' or 'Blue-white' or 'Blue white ' or 'Blue-White']
#       5 W = data[data["Star color"] == 'White' or 'Whitish' or 'white']
#       6 B = data[data["Star color"] == 'Blue' or 'Blue ']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data["Star color"].unique()
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)
