# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data.csv')

# %%
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
fig , ax = plt.subplots(figsize = (13,10))

plt.rcParams.update({'font.size': 14})

R = data[data["Star type"] == 0]
B = data[data["Star type"] == 1]
W = data[data["Star type"] == 2]
M = data[data["Star type"] == 3]
S = data[data["Star type"] == 4]
H = data[data["Star type"] == 5]

ax.scatter(np.log(R["Temperature (K)"]), np.log(R["Luminosity(L/Lo)"]),35, label = 'Red dwarfs', c = "red")
ax.scatter(np.log(B["Temperature (K)"]), np.log(B["Luminosity(L/Lo)"]),35, label = 'Brown dwarfs', c = "brown")
ax.scatter(np.log(W["Temperature (K)"]), np.log(W["Luminosity(L/Lo)"]),35, label = 'White dwarfs')
ax.scatter(np.log(M["Temperature (K)"]), np.log(M["Luminosity(L/Lo)"]),35, label = 'Main sequence stars')
ax.scatter(np.log(S["Temperature (K)"]), np.log(S["Luminosity(L/Lo)"]),35, label = 'Supergiants')
ax.scatter(np.log(H["Temperature (K)"]), np.log(H["Luminosity(L/Lo)"]),35, label = 'Hypergiants', c = "purple")

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.grid()

# %%
fig , ax = plt.subplots(figsize = (13,10))

sO = data[data["Spectral Class"] == 'O']
sB = data[data["Spectral Class"] == 'B']
sA = data[data["Spectral Class"] == 'A']
sF = data[data["Spectral Class"] == 'F']
sG = data[data["Spectral Class"] == 'G']
sK = data[data["Spectral Class"] == 'K']
sM = data[data["Spectral Class"] == 'M']

ax.scatter(np.log(sO["Temperature (K)"]), np.log(sO["Luminosity(L/Lo)"]),35, label = 'Spectral class O')
ax.scatter(np.log(sB["Temperature (K)"]), np.log(sB["Luminosity(L/Lo)"]),35, label = 'Spectral class B')
ax.scatter(np.log(sA["Temperature (K)"]), np.log(sA["Luminosity(L/Lo)"]),35, label = 'Spectral class A')
ax.scatter(np.log(sF["Temperature (K)"]), np.log(sF["Luminosity(L/Lo)"]),35, label = 'Spectral class F')
ax.scatter(np.log(sG["Temperature (K)"]), np.log(sG["Luminosity(L/Lo)"]),35, label = 'Spectral class G')
ax.scatter(np.log(sK["Temperature (K)"]), np.log(sK["Luminosity(L/Lo)"]),35, label = 'Spectral class K')
ax.scatter(np.log(sM["Temperature (K)"]), np.log(sM["Luminosity(L/Lo)"]),35, label = 'Spectral class M')

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.grid()

# %%
fig , ax = plt.subplots(figsize = (13,10))

R = data[data["Star color"] == 'Red']
BW = data[data["Star color"] == 'Blue White'] # or 'Blue white' or 'Blue-white' or 'Blue white ' or 'Blue-White']
BW.append(data[data["Star color"] == 'Blue white'])
BW.append(data[data["Star color"] == 'Blue-white'])
BW.append(data[data["Star color"] == 'Blue white '])
BW.append(data[data["Star color"] == 'Blue-White'])
W = data[data["Star color"] == 'White'] # or 'Whitish' or 'white']
W.append(data[data["Star color"] == 'Whitish'])
W.append(data[data["Star color"] == 'white'])
B = data[data["Star color"] == 'Blue'] # or 'Blue ']
B.append(data[data["Star color"] == 'Blue '])
O = data[data["Star color"] == 'Orange'] # or 'Orange-Red']
O.append(data[data["Star color"] == 'Orange-Red'])
YW = data[data["Star color"] == 'yellow-white'] # or 'White-Yellow' or 'Yellowish White']
YW.append(data[data["Star color"] == 'White-Yellow'])
YW.append(data[data["Star color"] == 'Yellowish White'])
Y = data[data["Star color"] == 'yellowish'] # or 'Yellowish']
Y.append(data[data["Star color"] == 'Yellowish'])
YO = data[data["Star color"] == 'Pale yellow orange']

ax.scatter(np.log(R["Temperature (K)"]), np.log(R["Luminosity(L/Lo)"]),35, label = 'Red', c = "#FF0000")
ax.scatter(np.log(BW["Temperature (K)"]), np.log(BW["Luminosity(L/Lo)"]),35, label = 'Blue White', c = "#C1F3FF")
ax.scatter(np.log(W["Temperature (K)"]), np.log(W["Luminosity(L/Lo)"]),35, label = 'White', c = "#FFFFFF")
ax.scatter(np.log(B["Temperature (K)"]), np.log(B["Luminosity(L/Lo)"]),35, label = 'Blue', c = "#009AFF")
ax.scatter(np.log(O["Temperature (K)"]), np.log(O["Luminosity(L/Lo)"]),35, label = 'Orange', c = "#FF8900")
ax.scatter(np.log(YW["Temperature (K)"]), np.log(YW["Luminosity(L/Lo)"]),35, label = 'Yellow White', c = "#FFF801")
ax.scatter(np.log(Y["Temperature (K)"]), np.log(Y["Luminosity(L/Lo)"]),35, label = 'Yellowish', c = "#FFF801")
ax.scatter(np.log(YO["Temperature (K)"]), np.log(YO["Luminosity(L/Lo)"]),35, label = 'Pale yellow orange', c = "#FFDA80")

ax.invert_xaxis()
ax.legend()
plt.xlabel("Temperature (K)")
plt.ylabel("Luminosity (L/Lo)")
ax.set_facecolor('#000000')

# %%
data["Star color"].unique()
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)

# %%
R = data[data["Star color"] == 'Red']

# %%
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                  16.120
# 1               3042          0.000500        0.1542                  16.600
# 2               2600          0.000300        0.1020                  18.700
# 3               2800          0.000200        0.1600                  16.650
# 4               1939          0.000138        0.1030                  20.060
# ..               ...               ...           ...                     ...
# 195             3598          0.002700        0.6700                  13.667
# 196             3142          0.001320        0.2580                  14.120
# 197             3496          0.001250        0.3360                  14.940
# 198             3324          0.006500        0.4710                  12.780
# 199             3463          0.002700        0.6750                  14.776
#
#      Star type Star color Spectral Class
# ...

# %%
sA = data[data["Spectral Class"] == 'A']

# %%
sA
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 21              7740           0.00049       0.01234                  14.020
# 23              8500           0.00050       0.01000                  14.500
# 26              8570           0.00081       0.00970                  14.200
# 35              8052           8.70000       1.80000                   2.420
# 82              8930           0.00056       0.00950                  13.780
# 85              9675           0.00045       0.01090                  13.980
# 94              9030          45.00000       2.63000                   1.450
# 95             11250         672.00000       6.98000                  -2.300
# 98             12098         689.00000       7.01000                   0.020
# 145             8924           0.00028       0.00879                  14.870
# 148             7723           0.00014       0.00878                  14.810
# ...

# %%
BW = data[data["Star color"] == 'Blue White'] # or 'Blue white' or 'Blue-white' or 'Blue white ' or 'Blue-White']
BW.append(data[data["Star color"] == 'Blue white'])
BW.append(data[data["Star color"] == 'Blue-white'])
BW.append(data[data["Star color"] == 'Blue white '])
BW.append(data[data["Star color"] == 'Blue-White'])
BW
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 20             25000           0.05600       0.00840                   10.58
# 24             16500           0.01300       0.01400                   11.89
# 83             17200           0.00098       0.01500                   12.45
# 84             14100           0.00067       0.00890                   12.17
# 85              9675           0.00045       0.01090                   13.98
# 86             12010           0.00078       0.00920                   12.13
# 87             10980           0.00074       0.00870                   11.19
# 140            13420           0.00059       0.00981                   13.67
# 143            14520           0.00082       0.00972                   11.92
# 149            12984           0.00088       0.00996                   11.23
#
#      Star type  Star color Spectral Class
# 20           2  Blue White              B
# ...

# %% [markdown]
# Start type prediction using Random Forest model
#
# Preparation of data:
# - data is shuffled
# - the star-type is separated from the rest of the data set
# - the categorical data (spectral type and star colour) is converted to numerical data
# - the set is divided into training and test data
#
# Random Forest model:
# - The training data is fitted to the Random Forest model
# - the score of the modelling is confirmed to be 1.0
# - The star-types of the test data are predicted using the model
# - the predictions are compared with the star-types given in the data set
# - The prediction is observed to be correct with the score of 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %% [markdown]
# Preparation of data:

# %%
# shuffle the data
data = data.sample(frac=1)

# star-type is separated from rest of the data set
# x is star characteristics and y is star types
x = data.drop("Star type", axis=1)
y = data["Star type"]

# the categorical data (spectral type and star colour) is converted to numerical data
categorical_features = ["Spectral Class", "Star color"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot",
                                 one_hot,
                                 categorical_features)],
                                remainder = "passthrough")
transformed_x = transformer.fit_transform(x)

# the set is divided into training and test data
x_train , x_test , y_train , y_test = train_test_split(transformed_x, y, test_size = 0.2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:395: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   check_array(X, dtype=np.int)
# ...

# %%
x_train
# Out:
# <192x30 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1152 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Random Forest model:

# %%
# The training data is fitted to the Random Forest model
model = RandomForestClassifier()
model.fit(x_train,y_train)

# the score of the modelling is confirmed to be 1.0
model.score(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:489: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_store_unique_indices = np.zeros(y.shape, dtype=np.int)
# ...

# %%
# The star-types of the test data are predicted using the model

y_preds = model.predict(x_test)
y_preds
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)
# array([2, 4, 5, 4, 5, 3, 0, 1, 5, 5, 5, 0, 2, 1, 2, 1, 4, 2, 5, 0, 1, 2,
#        3, 3, 0, 5, 1, 2, 0, 3, 4, 4, 3, 1, 2, 1, 3, 5, 3, 2, 3, 4, 3, 1,
#        5, 0, 2, 4])

# %%
# the predictions are compared with the star-types given in the data set
print(model.score(x_test,y_preds))
# Out:
# 1.0
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)
